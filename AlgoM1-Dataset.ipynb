# %%
import pandas as pd

# %%
df = pd.read_csv("https://bit.ly/world-cities-clean")

# %%
df.head()
# Out:
#                name               country          subcountry  geonameid
# 0      les Escaldes               Andorra  Escaldes-Engordany    3040051
# 1  Andorra la Vella               Andorra    Andorra la Vella    3041563
# 2    Umm al Qaywayn  United Arab Emirates      Umm al Qaywayn     290594
# 3    Ras al-Khaimah  United Arab Emirates     Raʼs al Khaymah     291074
# 4      Khawr Fakkān  United Arab Emirates        Ash Shāriqah     291696

# %%
#import pandas as pd
chemin = "chemin/qui/nexistepas"
data = pd.read_csv(chemin)
#Crash à cause du chemin qui n'existe pas
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-4e8c5efbb603> in <module>
#       1 #import pandas as pd
#       2 chemin = "chemin/qui/nexistepas"
# ----> 3 data = pd.read_csv(chemin)
#
# ...

# %%
## PARTIE COURS ##

# %%
#df.shape pour regarder le nombres de ligne et de colonnes
#df.dtypes pour regarder le nom des colonnes et leur type d'un seul coup (j'en profite pour repérer d'éventuel conversion de types qu'il faudra effectuer)
#df.head() pour regarder à quoi ressemble les premières lignes du dataset.
#df.tail() pour regarder les dernières lignes du dataset. J'en profite pour comparer le résultat de head avec celui de tail, y-a-t'il une quelconque différence? Parfois les anomalies sont rangées à la fin du dataset.
#df.isna().sum() pour vérifier la présence de valeurs manquantes par colonnes.

#df.drop('Open*', axis = 'columns', inplace = True)
#df = df.drop('Open*', axis = 'columns')

## FIN COURS ##

# %%
df2 = pd.read_csv("https://bit.ly/bitcoin-data")

# %%
df2
# Out:
#                                    Date    Open*     High      Low  Close**  \
# 0                           Jan 14 2020  8140.93  8879.51  8140.93  8827.76
# 1                           Jan 13 2020  8189.77  8197.79  8079.70  8144.19
# 2                           Jan 12 2020  8033.26  8200.06  8009.06  8192.49
# 3                           Jan 11 2020  8162.19  8218.36  8029.64  8037.54
# 4                           Jan 10 2020  7878.31  8166.55  7726.77  8166.55
# 5                           Jan 09 2020  8082.30  8082.30  7842.40  7879.07
# 6                           Jan 08 2020  8161.94  8396.74  7956.77  8079.86
# 7                           Jan 07 2020  7768.68  8178.22  7768.23  8163.69
# 8                           Jan 06 2020  7410.45  7781.87  7409.29  7769.22
# 9                           Jan 05 2020  7410.45  7544.50  7400.54  7411.32
# 10                          Jan 04 2020  7345.38  7427.39  7309.51  7410.66
# ...

# %%
df2.head()
# Out:
#           Date    Open*     High      Low  Close**        Volume    Market Cap
# 0  Jan 14 2020  8140.93  8879.51  8140.93  8827.76  4.484178e+10  1.603195e+11
# 1  Jan 13 2020  8189.77  8197.79  8079.70  8144.19  2.248291e+10  1.478905e+11
# 2  Jan 12 2020  8033.26  8200.06  8009.06  8192.49  2.290344e+10  1.487530e+11
# 3  Jan 11 2020  8162.19  8218.36  8029.64  8037.54  2.552117e+10  1.459242e+11
# 4  Jan 10 2020  7878.31  8166.55  7726.77  8166.55  2.871458e+10  1.482499e+11

# %%
toy = pd.DataFrame(data={'a': [1, 2],
                        'b': [3, 3]})

# %%
toy
# Out:
#    a  b
# 0  1  3
# 1  2  3

# %%
# Méthode 1
toy.rename(str.upper, 
          axis = 'columns',
          inplace = True)

# %%
# Méthode 2
toy.columns = toy.columns.str.upper()

# %%
############################
########DATA CLEANING#######
############################

# %%
#Processus de transformer une masse d'informations en quelque chose d'utilisable

# %%
#Dirty : date, texte, nombres
#Clean : numérique, catégorique, ordinal

# %%
'''Exemple dirty/clean
Version dirty (car hierarchisée)
B = 0
R = 1
v = 2

Version clean
B | R | V
1 | 0 | 0
0 | 1 | 0
0 | 0 | 1
1 | 0 | 0
0 | 0 | 1
'''
# Out:
# 'Exemple dirty/clean\nVersion dirty (car hierarchisée)\nB = 0\nR = 1\nv = 2\n\nVersion clean\nB | R | V\n1 | 0 | 0\n0 | 1 | 0\n0 | 0 | 1\n1 | 0 | 0\n0 | 0 | 1\n'

# %%
'''
str -> num
num -> ordinal
date -> num
date -> ordinal

NaN -> str, num, date -> catégorie
'''
# Out:
# '\nstr -> num\nnum -> ordinal\ndate -> num\ndate -> ordinal\n\nNaN -> str, num, date -> catégorie\n'

# %%
df2.shape
# Out:
# (33, 7)

# %%
df2.head
# Out:
# <bound method NDFrame.head of                                    Date    Open*     High      Low  Close**  \
# 0                           Jan 14 2020  8140.93  8879.51  8140.93  8827.76
# 1                           Jan 13 2020  8189.77  8197.79  8079.70  8144.19
# 2                           Jan 12 2020  8033.26  8200.06  8009.06  8192.49
# 3                           Jan 11 2020  8162.19  8218.36  8029.64  8037.54
# 4                           Jan 10 2020  7878.31  8166.55  7726.77  8166.55
# 5                           Jan 09 2020  8082.30  8082.30  7842.40  7879.07
# 6                           Jan 08 2020  8161.94  8396.74  7956.77  8079.86
# 7                           Jan 07 2020  7768.68  8178.22  7768.23  8163.69
# 8                           Jan 06 2020  7410.45  7781.87  7409.29  7769.22
# 9                           Jan 05 2020  7410.45  7544.50  7400.54  7411.32
# 10                          Jan 04 2020  7345.38  7427.39  7309.51  7410.66
# ...

# %%
df2.dtypes
# Out:
# Date           object
# Open*         float64
# High          float64
# Low           float64
# Close**       float64
# Volume        float64
# Market Cap    float64
# dtype: object

# %%
#df2['wire amount'] = df2['wire amount'].str.slice(1, None)

# %%
import random

# %%
def makeNumberStr(sep=[',']):
    avant = str(random.randint(1, 1000))
    apres = '{:02}'.format(random.randint(0,99))
    sep = random.choice(sep)
    return avant + sep + apres

# %%
col1 = [makeNumberStr() for _ in range(200)]
col2 = [makeNumberStr(['.', ',']) for _ in range(200)]

# %%
#print(abcd)

# %%
#exo2['col1'] = exo2['col1'].str.replace(',','.')
#exo2['col2'] = exo2['col2'].str.replace(',','.')

#exo2['Device col1'] = exo2['col1'].str.get(-1)
#exo2['col1'] = exo2['col1'].str.slice(None, -1).astype('float')
#exo2['Device col2'] = exo2['col2'].str.get(-1)
#exo2['col2'] = exo2['col2'].str.slice(None, -1).astype('float')

#Boucle

#for i in [1,2]:
#	exo2[f'col{i}'] = exo2[f'col{i}'].str.replace(',','.')
#	exo2[f'Devise col{i}'] = exo2[f'col{i}'.get.get(-1)
#	exo2[f'col{i}'] = exo2{f'col{i}'].str.slice(None, -1).astype('float)
